# %%
import spotipy
from spotipy.oauth2 import SpotifyOAuth
import cred
import streamlit as st
import pandas as pd

# %%
scope = "user-read-recently-played"
scope = "user-library-read"

sp = spotipy.Spotify(auth_manager=SpotifyOAuth(client_id=cred.client_id, client_secret= cred.client_secret, redirect_uri=cred.redirect_url, scope=scope))

album_url = "4aawyAB9vmqN3uQ7FjRGTy"

# st.text_input(label="Please input the album's url:")
# st.write(type(album_url))
# st.write(sp.album(album_url))


# try:
#     type(album_url) is str
# except:
#     st.error('You need to enter a url')
#     st.stop()


album = sp.album(album_url)
album_upc = album['external_ids']['upc']
album_artist = album['artists'][0]['name']
album_title = album['name']
album_track_number = album['total_tracks']
# st.write(album_upc,'-',album_artist,'-', album_title, '-', album_track_number)

tracks_list = []

for i in range(album_track_number):
    track_number = album['tracks']['items'][i]['track_number']
    track_name = album['tracks']['items'][i]['name']
    track_artists = album['tracks']['items'][i]['artists'][0]['name']
    track_url = album['tracks']['items'][i]['external_urls']['spotify']
    # st.write(track_number, '-', track_name, '-', track_artists, '-', track_url)
    
    tracks_list.append({
                "Track Number": track_number,
                "Title": track_name,
                "Artist": track_artists,
                "URL": track_url
            })

        # Créer le DataFrame à partir de la liste de dictionnaires
df_tracks = pd.DataFrame(tracks_list)
# st.dataframe(df_tracks, use_container_width=True)
print(df_tracks)
# Out:
#     Track Number                                              Title   Artist  \
# 0              1                     Global Warming (feat. Sensato)  Pitbull
# 1              2                   Don't Stop the Party (feat. TJR)  Pitbull
# 2              3        Feel This Moment (feat. Christina Aguilera)  Pitbull
# 3              4        Back in Time - featured in "Men In Black 3"  Pitbull
# 4              5             Hope We Meet Again (feat. Chris Brown)  Pitbull
# 5              6          Party Ain't Over (feat. Usher & Afrojack)  Pitbull
# 6              7       Drinks for You (Ladies Anthem) (feat. J. Lo)  Pitbull
# 7              8        Have Some Fun (feat. The Wanted & Afrojack)  Pitbull
# 8              9                 Outta Nowhere (feat. Danny Mercer)  Pitbull
# 9             10            Tchu Tchu Tcha (feat. Enrique Iglesias)  Pitbull
# 10            11         Last Night (feat. Afrojack & Havana Brown)  Pitbull
# 11            12                                       I'm Off That  Pitbull
# 12            13        Echa Pa'lla (Manos Pa'rriba) (feat. Papayo)  Pitbull
# 13            14          Everybody Fucks (feat. Akon & David Rush)  Pitbull
# 14            15                     Get It Started (feat. Shakira)  Pitbull
# 15            16                                 11:59 (feat. Vein)  Pitbull
# 16            17  Rain Over Me (feat. Marc Anthony) - Benny Bena...  Pitbull
# 17            18  International Love (feat. Chris Brown) - Jump ...  Pitbull
#
#                                                   URL
# 0   https://open.spotify.com/track/6OmhkSOpvYBokMK...
# 1   https://open.spotify.com/track/2iblMMIgSznA464...
# 2   https://open.spotify.com/track/4yOn1TEcfsKHUJC...
# 3   https://open.spotify.com/track/7fmpKF0rLGPnP7k...
# 4   https://open.spotify.com/track/3jStb2imKd6oUoB...
# 5   https://open.spotify.com/track/6Q4PYJtrq8CBx7Y...
# 6   https://open.spotify.com/track/0QTVwqcOsYd73AO...
# 7   https://open.spotify.com/track/10Sydb6AAFPdgCz...
# 8   https://open.spotify.com/track/4k61iDqmtX9nI7R...
# 9   https://open.spotify.com/track/7oGRkL31ElVMcev...
# 10  https://open.spotify.com/track/60xPqMqnHZl7Jfi...
# 11  https://open.spotify.com/track/1jAdXqOSICyXYLa...
# 12  https://open.spotify.com/track/0fjRYHFz9ealui1...
# 13  https://open.spotify.com/track/7of35ktwTbL906Z...
# 14  https://open.spotify.com/track/2JA6A6Y5f4m7Paw...
# 15  https://open.spotify.com/track/726qZxwhP0jVyIA...
# 16  https://open.spotify.com/track/6GPER1Sx8MrBiwW...
# 17  https://open.spotify.com/track/4TWgcICXXfGty8M...

# %%
scope = "user-top-read"
sp = spotipy.Spotify(auth_manager=SpotifyOAuth(client_id=cred.client_id, client_secret= cred.client_secret, redirect_uri=cred.redirect_url
#                                                , scope=scope
                                              ))



# recommendations = sp.recommendations(
#     # seed_genres=["pop", "rock"],
#     target_danceability=danceability,
#     target_energy=energy,
# #     limit=20 # Nombre de titres à recommander
# )

print("")

# %%
import requests

url = "https://api.reccobeats.com/v1/audio-features"

#Sound of silence - Simon & Garfunkel
track_ids = "5y788ya4NvwhBznoDIcXwK"
params = {
    'ids': track_ids
}

headers = {
  'Accept': 'application/json'
}

response = requests.get(url, params=params
#                         , headers=headers 
                       )

if response.status_code == 200:
    print(response.json())
else:
    print(f"Erreur : {response.status_code}")
    print(response.text)
# Out:
# {'content': [{'id': 'd62264f9-9f6e-4bf1-a635-b8fbf27bdde7', 'acousticness': 0.837, 'danceability': 0.525, 'energy': 0.216, 'instrumentalness': 0.0, 'liveness': 0.107, 'loudness': -13.551, 'speechiness': 0.0301, 'tempo': 106.761, 'valence': 0.328}]}

# %%
# Reccobeats 
# Get recommendations
import requests

url = "https://api.reccobeats.com/v1/track/recommendation"
track_ids = ["5y788ya4NvwhBznoDIcXwK"]
params = {
    'size' : 2, 
    'seeds': track_ids
}

headers = {
  'Accept': 'application/json'
}

response = requests.get(url, params=params
#                         , headers=headers 
                       )

if response.status_code == 200:
    print(response.json())
else:
    print(f"Erreur : {response.status_code}")
    print(response.text)
# Out:
# {'content': [{'id': '2ea94191-e399-4a24-8c10-2267d06718ce', 'trackTitle': 'Silver Sable', 'artists': [{'id': '4cbc0ff8-2382-4839-87a1-ef95af771b5a', 'name': 'Cigarettes After Sex', 'href': 'https://open.spotify.com/artist/1QAJqy2dA3ihHBFIHRphZj'}], 'durationMs': 231933, 'isrc': 'USBQU2400003', 'ean': None, 'upc': None, 'href': 'https://open.spotify.com/track/3xQgvGwf3KnaYry1b